# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import cv2

# %%
image1 = plt.imread("/content/Fig0316(1)(top_left).tif")
image2 = plt.imread("/content/Fig0320(1)(top_left).tif")
image3 = plt.imread("/content/Fig0316(2)(2nd_from_top).tif")
image4 = plt.imread("/content/Fig0320(2)(2nd_from_top).tif")
image5 = plt.imread("/content/Fig0316(3)(third_from_top).tif")
image6 = plt.imread("/content/Fig0320(3)(third_from_top).tif")
image7 = plt.imread("/content/Fig0316(4)(bottom_left).tif")
image8 = plt.imread("/content/Fig0320(4)(bottom_left).tif")

fig = plt.figure(figsize=(10,10))
columns = 4
rows = 4

fig.add_subplot(rows,columns,1)
plt.imshow(image1,"gray")
plt.axis("off")
plt.title("image-1")
fig.add_subplot(rows,columns,2)
plt.hist(image1)
plt.axis("off")
plt.title("hist-1")

fig.add_subplot(rows,columns,3)
plt.imshow(image2,"gray")
plt.axis("off")
plt.title("image-2")
fig.add_subplot(rows,columns,4)
plt.hist(image2)
plt.axis("off")
plt.title("hist-2")

fig.add_subplot(rows,columns,5)
plt.imshow(image3,"gray")
plt.axis("off")
plt.title("image-3")
fig.add_subplot(rows,columns,6)
plt.hist(image3)
plt.axis("off")
plt.title("hist-3")

fig.add_subplot(rows,columns,7)
plt.imshow(image4,"gray")
plt.axis("off")
plt.title("image-4")
fig.add_subplot(rows,columns,8)
plt.hist(image4)
plt.axis("off")
plt.title("hist-4")

fig.add_subplot(rows,columns,9)
plt.imshow(image5,"gray")
plt.axis("off")
plt.title("image-5")
fig.add_subplot(rows,columns,10)
plt.hist(image5)
plt.axis("off")
plt.title("hist-5")

fig.add_subplot(rows,columns,11)
plt.imshow(image6,"gray")
plt.axis("off")
plt.title("image-6")
fig.add_subplot(rows,columns,12)
plt.hist(image6)
plt.axis("off")
plt.title("hist-6")

fig.add_subplot(rows,columns,13)
plt.imshow(image7,"gray")
plt.axis("off")
plt.title("image-7")
fig.add_subplot(rows,columns,14)
plt.hist(image7)
plt.axis("off")
plt.title("hist-7")

fig.add_subplot(rows,columns,15)
plt.imshow(image8,"gray")
plt.axis("off")
plt.title("image-8")
fig.add_subplot(rows,columns,16)
plt.hist(image8)
plt.axis("off")
plt.title("hist-8")
# Out:
# Text(0.5, 1.0, 'hist-8')
